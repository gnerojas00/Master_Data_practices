# %% [markdown]
# <a href="https://colab.research.google.com/github/gnerojas00/Master_Data_practices/blob/main/Copia_de_Genesis_rojas_alvarez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dado que el entrenamiento de redes neuronales es una tarea  muy costosa, **se recomienda ejecutar el notebooks en [Google Colab](https://colab.research.google.com)**, por supuesto también se puede ejecutar en local.
#
# Al entrar en [Google Colab](https://colab.research.google.com) bastará con hacer click en `upload` y subir este notebook. No olvide luego descargarlo en `File->Download .ipynb`
#
# **El examen deberá ser entregado con las celdas ejecutadas, si alguna celda no está ejecutadas no se contará.**

# %% [markdown]
# El examen se divide en dos partes, con la puntuación que se indica a continuación. La puntuación máxima será 10.
#
# - [Actividad 1: Redes Densas](#actividad_1): 5 pts
#     - Correcta normalización: máximo de 0.25 pts
#     - [Cuestión 1](#1.1): 1.5 pt
#     - [Cuestión 2](#1.2): 1.5 pt
#     - [Cuestión 3](#1.3): 0.5 pts
#     - [Cuestión 4](#1.4): 0.25 pts
#     - [Cuestión 5](#1.5): 0.25 pts
#     - [Cuestión 6](#1.6): 0.25 pts
#     - [Cuestión 7](#1.7): 0.25 pts
#     - [Cuestión 8](#1.8): 0.25 pts
#
#
# - [Actividad 2: Redes Convolucionales](#actividad_2): 5 pts
#     - [Cuestión 1](#2.1): 2.5 pt
#     - [Cuestión 2](#2.2): 1 pt
#     - [Cuestión 3](#2.3): 0.5 pts
#     - [Cuestión 4](#2.4): 0.5 pts
#     - [Cuestión 5](#2.5): 0.5 pts

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
tf.random.set_seed(0)
from tensorflow.keras import layers, models

# %% [markdown]
# <a name='actividad_1'></a>
# # Actividad 1: Redes Densas
#
# Para esta primera actividad vamos a utilizar el [wine quality dataset](https://archive.ics.uci.edu/ml/datasets/wine+quality). Con el que trataremos de predecir la calidad del vino.
#
# La calidad del vino puede tomar valores decimales (por ejemplo 7.25), independientemente de que en el dataset de entrenamiento sean números enteros. Por lo tanto, el problema es una `regresión`.
#
# **Puntuación**:
#
# Normalizar las features correctamente (x_train, x_test): 0.25 pts , se pueden normalizar con el [Normalization layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/Normalization) de Keras.
#
#
# - Correcta normalización: máximo de 0.25 pts
# - [Cuestión 1](#1.1): 1 pt
# - [Cuestión 2](#1.2): 1 pt
# - [Cuestión 3](#1.3): 0.5 pts
# - [Cuestión 4](#1.4): 0.25 pts
# - [Cuestión 5](#1.5): 0.25 pts
# - [Cuestión 6](#1.6): 0.25 pts
# - [Cuestión 7](#1.7): 0.25 pts
# - [Cuestión 8](#1.8): 0.25 pts

# %%
# Descargar los datos con pandas
df_red = pd.read_csv(
    'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv',
    sep=';'
)
df_white = pd.read_csv(
    'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv',
    sep=';'
)
df = pd.concat([df_red, df_white])

df.head()

df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3, 9])

# %%
feature_names = [
    'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides',
    'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol'
]



y = df.pop('quality').values
X = df.copy().values

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

print('x_train, y_train shapes:', x_train.shape, y_train.shape)
print('x_test, y_test shapes:', x_test.shape, y_test.shape)
print('Some qualities: ', y_train[:5])
# Out:
# x_train, y_train shapes: (4872, 11) (4872,)
# x_test, y_test shapes: (1625, 11) (1625,)
# Some qualities:  [6 7 8 5 6]

# %%
from tensorflow.keras.layers import Normalization

normalizer = Normalization()

normalizer.adapt(x_train)

x_train = normalizer(x_train)
x_test = normalizer(x_test)

# %% [markdown]
# <a name='1.1'></a>
# ## Cuestión 1: Cree un modelo secuencial que contenga 4 capas ocultas(hidden layers), con más de 60 neuronas  por capa, sin regularización y obtenga los resultados.
#
# Puntuación:
# - Obtener el modelo correcto: 0.8 pts
# - Compilar el modelo: 0.1pts
# - Acertar con la función de pérdida: 0.1 pts

# %%
from tensorflow.keras import layers, models

model = tf.keras.models.Sequential()
# Código aquí


model.add(layers.Dense(161, activation='relu', input_shape=(x_train.shape[1],)))
model.add(layers.Dense(150, activation='relu'))
model.add(layers.Dense(160, activation='relu'))
model.add(layers.Dense(161, activation='relu'))
model.add(layers.Dense(1))


model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 161)            │         1,932 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 150)            │        24,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 160)            │        24,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 161)            │        25,921 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │           162 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 76,475 (298.73 KB)
#  Trainable params: 76,475 (298.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilación del modelo
# Código aquí
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
# No modifique el código
model.fit(x_train,
          y_train,
          epochs=200,
          batch_size=32,
          validation_split=0.2,
          verbose=1)
# Out:
# Epoch 1/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 9.3392 - mae: 2.2699 - val_loss: 1.3968 - val_mae: 0.8700
# Epoch 2/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0276 - mae: 0.7910 - val_loss: 0.7799 - val_mae: 0.6782
# Epoch 3/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6276 - mae: 0.6155 - val_loss: 0.6340 - val_mae: 0.6137
# Epoch 4/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5249 - mae: 0.5657 - val_loss: 0.5998 - val_mae: 0.5967
# Epoch 5/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4892 - mae: 0.5476 - val_loss: 0.5877 - val_mae: 0.5921
# Epoch 6/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4698 - mae: 0.5363 - val_loss: 0.5829 - val_mae: 0.5903
# Epoch 7/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4567 - mae: 0.5281 - val_loss: 0.5781 - val_mae: 0.5878
# Epoch 8/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4439 - mae: 0.5203 - val_loss: 0.5733 - val_mae: 0.5853
# Epoch 9/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4325 - mae: 0.5138 - val_loss: 0.5684 - val_mae: 0.5825
# Epoch 10/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4243 - mae: 0.5091 - val_loss: 0.5696 - val_mae: 0.5849
# Epoch 11/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4161 - mae: 0.5035 - val_loss: 0.5731 - val_mae: 0.5855
# Epoch 12/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4066 - mae: 0.4982 - val_loss: 0.5674 - val_mae: 0.5832
# Epoch 13/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4004 - mae: 0.4947 - val_loss: 0.5745 - val_mae: 0.5871
# Epoch 14/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3935 - mae: 0.4898 - val_loss: 0.5680 - val_mae: 0.5831
# Epoch 15/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3839 - mae: 0.4837 - val_loss: 0.5715 - val_mae: 0.5860
# Epoch 16/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3745 - mae: 0.4770 - val_loss: 0.5840 - val_mae: 0.5912
# Epoch 17/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3692 - mae: 0.4750 - val_loss: 0.5780 - val_mae: 0.5879
# Epoch 18/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3617 - mae: 0.4692 - val_loss: 0.5780 - val_mae: 0.5886
# Epoch 19/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.
200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0438 - mae: 0.1605 - val_loss: 0.5085 - val_mae: 0.5064
# Epoch 185/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0396 - mae: 0.1518 - val_loss: 0.5020 - val_mae: 0.5077
# Epoch 186/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0379 - mae: 0.1472 - val_loss: 0.5038 - val_mae: 0.5073
# Epoch 187/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0390 - mae: 0.1520 - val_loss: 0.5140 - val_mae: 0.5163
# Epoch 188/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0376 - mae: 0.1470 - val_loss: 0.5033 - val_mae: 0.5095
# Epoch 189/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0395 - mae: 0.1526 - val_loss: 0.5096 - val_mae: 0.5153
# Epoch 190/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0414 - mae: 0.1544 - val_loss: 0.5154 - val_mae: 0.5149
# Epoch 191/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0410 - mae: 0.1547 - val_loss: 0.5233 - val_mae: 0.5176
# Epoch 192/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mae: 0.1676 - val_loss: 0.5124 - val_mae: 0.5208
# Epoch 193/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0461 - mae: 0.1636 - val_loss: 0.5024 - val_mae: 0.5140
# Epoch 194/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0476 - mae: 0.1705 - val_loss: 0.5092 - val_mae: 0.5163
# Epoch 195/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0564 - mae: 0.1846 - val_loss: 0.5147 - val_mae: 0.5298
# Epoch 196/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0654 - mae: 0.2025 - val_loss: 0.5614 - val_mae: 0.5658
# Epoch 197/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0728 - mae: 0.2125 - val_loss: 0.5720 - val_mae: 0.5666
# Epoch 198/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0730 - mae: 0.2067 - val_loss: 0.5424 - val_mae: 0.5426
# Epoch 199/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0758 - mae: 0.2170 - val_loss: 0.5256 - val_mae: 0.5224
# Epoch 200/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0580 - mae: 0.1864 - val_loss: 0.5118 - val_mae: 0.5200

# %%
# No modifique el código
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results))
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5356 - mae: 0.5319
# Test Loss: [0.5533407330513, 0.5359736680984497]

# %% [markdown]
# <a name='1.2'></a>
# ## Cuestión 2: Utilice el mismo modelo de la cuestión anterior pero añadiendo al menos dos técnicas distinas de regularización.
#
# Ejemplos de regularización: [Prevent_Overfitting.ipynb](https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/Prevent_Overfitting.ipynb)
#
# Puntuación:
#
# - Obtener el modelo con la regularización: 0.8 pts
# - Obtener un `test loss` inferior al anterior: 0.2 pts

# %%
from tensorflow.keras import layers, models, regularizers
model = tf.keras.models.Sequential()
# Código aquí

model.add(layers.Dense(141, activation='relu',
                       input_shape=(x_train.shape[1],)))

model.add(layers.Dense(150, activation='relu',
                       kernel_regularizer=regularizers.l2(0.0001)))
model.add(layers.Dropout(0.4))

model.add(layers.Dense(160, activation='relu',
                       kernel_regularizer=regularizers.l2(0.0001)))
model.add(layers.Dropout(0.4))

model.add(layers.Dense(161, activation='relu',
                       kernel_regularizer=regularizers.l2(0.0001)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(1))


model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 141)            │         1,692 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 150)            │        21,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 160)            │        24,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 161)            │        25,921 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 161)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │           162 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,235 (286.07 KB)
#  Trainable params: 73,235 (286.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilación del modelo
# Código aquí
model.compile(optimizer='adam', loss='mse', metrics=['mae'])  # o también 'mape', 'rmse' si defines una métrica personalizada

# %%
batch_size= 16

# %%
# No modifique el código
model.fit(x_train,
          y_train,
          epochs=200,
          batch_size=batch_size,
          validation_split=0.2,
          verbose=1)
# Out:
# Epoch 1/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 8.3615 - mae: 2.1956 - val_loss: 1.3716 - val_mae: 0.9101
# Epoch 2/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 1.8954 - mae: 1.0713 - val_loss: 0.9083 - val_mae: 0.7291
# Epoch 3/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.3148 - mae: 0.8811 - val_loss: 0.6742 - val_mae: 0.6062
# Epoch 4/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0759 - mae: 0.7951 - val_loss: 0.6889 - val_mae: 0.6174
# Epoch 5/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9700 - mae: 0.7542 - val_loss: 0.5803 - val_mae: 0.5682
# Epoch 6/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9383 - mae: 0.7435 - val_loss: 0.6052 - val_mae: 0.5828
# Epoch 7/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9408 - mae: 0.7408 - val_loss: 0.6674 - val_mae: 0.6135
# Epoch 8/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8590 - mae: 0.7081 - val_loss: 0.5702 - val_mae: 0.5668
# Epoch 9/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8576 - mae: 0.7048 - val_loss: 0.5870 - val_mae: 0.5700
# Epoch 10/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8279 - mae: 0.6910 - val_loss: 0.6619 - val_mae: 0.6153
# Epoch 11/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8212 - mae: 0.6899 - val_loss: 0.5651 - val_mae: 0.5647
# Epoch 12/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8422 - mae: 0.7039 - val_loss: 0.6534 - val_mae: 0.6087
# Epoch 13/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8126 - mae: 0.6982 - val_loss: 0.6343 - val_mae: 0.5975
# Epoch 14/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7709 - mae: 0.6664 - val_loss: 0.5402 - val_mae: 0.5533
# Epoch 15/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7441 - mae: 0.6551 - val_loss: 0.5143 - val_mae: 0.5395
# Epoch 16/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7585 - mae: 0.6643 - val_loss: 0.5939 - val_mae: 0.5808
# Epoch 17/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7093 - mae: 0.6449 - val_loss: 0.5388 - val_mae: 0.5429
# Epoch 18/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7661 - mae: 0.6680 - val_loss: 0.5537 - val_mae: 0.5481
# Epoch 19/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7100 - mae: 0.6444 - val_loss: 0.5915 - val_mae: 0.5772
# Epoch 20/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7183 - mae: 0.6517 - val_loss: 0.5301 - val_mae: 0.5428
# Epoch 21/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6991 - mae: 0.6374 - val_loss: 0.5282 - val_mae: 0.5379
# Epoch 22/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7245 - mae: 0.6399 - val_loss: 0.5347 - val_mae: 0.5422
# Epoch 23/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6953 - mae: 0.6385 - val_loss: 0.5045 - val_mae: 0.5251
# Epoch 24/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6826 - mae: 0.6352 - val_loss: 0.5845 - val_mae: 0.5665
# Epoch 25/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6712 - mae: 0.6268 - val_loss: 0.5411 - val_mae: 0.5446
# Epoch 26/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6951 - mae: 0.6378 - val_loss: 0.5839 - val_mae: 0.5712
# Epoch 27/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6504 - mae: 0.6130 - val_loss: 0.5892 - val_mae: 0.5704
# Epoch 28/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6594 - mae: 0.6198 - val_loss: 0.6041 - val_mae: 0.5773
# Epoch 29/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6548 - mae: 0.6189 - val_loss: 0.5709 - val_mae: 0.5633
# Epoch 30/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6129 - mae: 0.6004 - val_loss: 0.5559 - val_mae: 0.5445
# Epoch 31/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.
200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2680 - mae: 0.3568 - val_loss: 0.5018 - val_mae: 0.4904
# Epoch 197/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2635 - mae: 0.3551 - val_loss: 0.4835 - val_mae: 0.4852
# Epoch 198/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2722 - mae: 0.3619 - val_loss: 0.4844 - val_mae: 0.4847
# Epoch 199/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2864 - mae: 0.3728 - val_loss: 0.4713 - val_mae: 0.4802
# Epoch 200/200
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2695 - mae: 0.3575 - val_loss: 0.4798 - val_mae: 0.4821

# %%
# No modifique el código
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results))
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4792 - mae: 0.4864
# Test Loss: [0.5097160935401917, 0.49771708250045776]

# %% [markdown]
# <a name='1.3'></a>
# ## Cuestión 3: Utilice el mismo modelo de la cuestión anterior pero añadiendo un callback de early stopping.

# %%
from tensorflow.keras.callbacks import EarlyStopping

model = tf.keras.models.Sequential()


model.add(layers.Dense(141, activation='relu',
                      input_shape=(x_train.shape[1],)))


model.add(layers.Dense(150, activation='relu',
                      kernel_regularizer=regularizers.l2(0.0001)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(160, activation='relu',
                      kernel_regularizer=regularizers.l2(0.0001)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(161, activation='relu',
                      kernel_regularizer=regularizers.l2(0.0001)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(1))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compilación del modelo
# Código aquí
model.compile(optimizer='adam',
              loss='mse',
              metrics=['mae'])

# %%
## definir el early stopping callback
# Código aquí


early_stop = EarlyStopping(
    monitor='val_mae',
    patience=15,
    mode='min',
    restore_best_weights=True
)

model.fit(x_train,
          y_train,
          epochs=200,
          batch_size=32,
          validation_split=0.2,
          verbose=1,
          callbacks=[early_stop])
# Out:
# Epoch 1/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 10.6355 - mae: 2.5815 - val_loss: 2.4386 - val_mae: 1.2550
# Epoch 2/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2.2754 - mae: 1.1929 - val_loss: 1.1427 - val_mae: 0.8219
# Epoch 3/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5985 - mae: 0.9862 - val_loss: 1.1923 - val_mae: 0.8695
# Epoch 4/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3188 - mae: 0.8945 - val_loss: 0.7940 - val_mae: 0.6713
# Epoch 5/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0929 - mae: 0.7940 - val_loss: 0.6175 - val_mae: 0.5797
# Epoch 6/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0636 - mae: 0.7971 - val_loss: 0.5696 - val_mae: 0.5563
# Epoch 7/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0122 - mae: 0.7801 - val_loss: 0.5978 - val_mae: 0.5705
# Epoch 8/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9590 - mae: 0.7506 - val_loss: 0.6648 - val_mae: 0.6052
# Epoch 9/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.9523 - mae: 0.7445 - val_loss: 0.5793 - val_mae: 0.5651
# Epoch 10/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.8963 - mae: 0.7310 - val_loss: 0.5946 - val_mae: 0.5790
# Epoch 11/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.9350 - mae: 0.7423 - val_loss: 0.5535 - val_mae: 0.5563
# Epoch 12/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8898 - mae: 0.7152 - val_loss: 0.5325 - val_mae: 0.5469
# Epoch 13/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8942 - mae: 0.7186 - val_loss: 0.5048 - val_mae: 0.5313
# Epoch 14/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8600 - mae: 0.7161 - val_loss: 0.5551 - val_mae: 0.5551
# Epoch 15/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8254 - mae: 0.6921 - val_loss: 0.5376 - val_mae: 0.5447
# Epoch 16/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8656 - mae: 0.7166 - val_loss: 0.5230 - val_mae: 0.5472
# Epoch 17/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7990 - mae: 0.6902 - val_loss: 0.5381 - val_mae: 0.5431
# Epoch 18/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.8099 - mae: 0.6930 - val_loss: 0.5559 - val_mae: 0.5589
# Epoch 19/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8566 - mae: 0.7056 - val_loss: 0.5405 - val_mae: 0.5487
# Epoch 20/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7903 - mae: 0.6811 - val_loss: 0.5595 - val_mae: 0.5600
# Epoch 21/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7985 - mae: 0.6807 - val_loss: 0.5314 - val_mae: 0.5501
# Epoch 22/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7781 - mae: 0.6734 - val_loss: 0.5346 - val_mae: 0.5499
# Epoch 23/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8170 - mae: 0.7019 - val_loss: 0.5212 - val_mae: 0.5409
# Epoch 24/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7208 - mae: 0.6530 - val_loss: 0.5142 - val_mae: 0.5315
# Epoch 25/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7437 - mae: 0.6579 - val_loss: 0.5366 - val_mae: 0.5405
# Epoch 26/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7207 - mae: 0.6469 - val_loss: 0.5069 - val_mae: 0.5247
# Epoch 27/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7080 - mae: 0.6442 - val_loss: 0.5452 - val_mae: 0.5451
# Epoch 28/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7483 - mae: 0.6585 - val_loss: 0.5401 - val_mae: 0.5412
# Epoch 29/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7182 - mae: 0.6507 - val_loss: 0.5148 - val_mae: 0.5284
# Epoch 30/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7141 - mae: 0.6412 - val_loss: 0.5038 - val_mae: 0.5253
# Epoch 31/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6628 - mae: 0.6259 - val_loss: 0.5499 - val_mae: 0.5507
# Epoch 32/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7188 - mae: 0.6460 - val_loss: 0.5485 - val_mae: 0.5478
# Epoch 33/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7027 - mae: 0.6390 - val_loss: 0.5007 - val_mae: 0.5262
# Epoch 34/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6684 - mae: 0.6294 - val_loss: 0.5224 - val_mae: 0.5382
# Epoch 35/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7006 - mae: 0.6458 - val_loss: 0.4974 - val_mae: 0.5213
# Epoch 36/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6504 - mae: 0.6189 - val_loss: 0.5081 - val_mae: 0.5293
# Epoch 37/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6626 - mae: 0.6218 - val_loss: 0.5117 - val_mae: 0.5334
# Epoch 38/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6468 - mae: 0.6139 - val_loss: 0.5042 - val_mae: 0.5181
# Epoch 39/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6496 - mae: 0.6082 - val_loss: 0.5095 - val_mae: 0.5278
# Epoch 40/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6539 - mae: 0.6254 - val_loss: 0.5066 - val_mae: 0.5280
# Epoch 41/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6340 - mae: 0.5997 - val_loss: 0.5146 - val_mae: 0.5278
# Epoch 42/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6621 - mae: 0.6230 - val_loss: 0.5083 - val_mae: 0.5265
# Epoch 43/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6555 - mae: 0.6159 - val_loss: 0.5035 - val_mae: 0.5279
# Epoch 44/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6380 - mae: 0.6103 - val_loss: 0.5048 - val_mae: 0.5270
# Epoch 45/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6141 - mae: 0.5985 - val_loss: 0.5092 - val_mae: 0.5281
# Epoch 46/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6356 - mae: 0.6066 - val_loss: 0.5045 - val_mae: 0.5281
# Epoch 47/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6165 - mae: 0.6028 - val_loss: 0.5134 - val_mae: 0.5302
# Epoch 48/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6293 - mae: 0.6062 - val_loss: 0.4955 - val_mae: 0.5120
# Epoch 49/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6504 - mae: 0.6165 - val_loss: 0.4922 - val_mae: 0.5167
# Epoch 50/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6026 - mae: 0.5976 - val_loss: 0.4951 - val_mae: 0.5261
# Epoch 51/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5806 - mae: 0.5903 - val_loss: 0.4999 - val_mae: 0.5223
# Epoch 52/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6028 - mae: 0.5979 - val_loss: 0.4998 - val_mae: 0.5177
# Epoch 53/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5879 - mae: 0.5840 - val_loss: 0.5191 - val_mae: 0.5277
# Epoch 54/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5830 - mae: 0.5775 - val_loss: 0.4980 - val_mae: 0.5213
# Epoch 55/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5750 - mae: 0.5817 - val_loss: 0.5083 - val_mae: 0.5270
# Epoch 56/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5903 - mae: 0.5873 - val_loss: 0.5040 - val_mae: 0.5232
# Epoch 57/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5929 - mae: 0.5842 - val_loss: 0.4969 - val_mae: 0.5231
# Epoch 58/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5713 - mae: 0.5701 - val_loss: 0.5009 - val_mae: 0.5285
# Epoch 59/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5328 - mae: 0.5580 - val_loss: 0.4836 - val_mae: 0.5217
# Epoch 60/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5690 - mae: 0.5780 - val_loss: 0.4888 - val_mae: 0.5189
# Epoch 61/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5596 - mae: 0.5704 - val_loss: 0.4804 - val_mae: 0.5204
# Epoch 62/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5270 - mae: 0.5513 - val_loss: 0.5240 - val_mae: 0.5369
# Epoch 63/200
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5513 - mae: 0.5645 - val_loss: 0.4901 - val_mae: 0.5175

# %%
# No modifique el código
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results))

# %% [markdown]
# <a name='1.4'></a>
# ## Cuestión 4: ¿Podría haberse usado otra función de activación de la neurona de salida? En caso afirmativo especifíquela.

# %% [markdown]
# <a name='1.5'></a>
# ## Cuestión 5:  ¿Qué es lo que una neurona calcula?
#
# **a)** Una función de activación seguida de una suma ponderada  de las entradas.
#
# **b)** Una suma ponderada  de las entradas seguida de una función de activación.
#
# **c)** Una función de pérdida, definida sobre el target.
#
# **d)** Ninguna  de las anteriores es correcta

# %% [markdown]
# b

# %% [markdown]
# <a name='1.6'></a>
# ## Cuestión 6:  ¿Cuál de estas funciones de activación no debería usarse en una capa oculta (hidden layer)?
#
# **a)** `sigmoid`
#
# **b)** `tanh`
#
# **c)** `relu`
#
# **d)** `linear`

# %% [markdown]
# d

# %% [markdown]
# <a name='1.7'></a>
# ## Cuestión 7:  ¿Cuál de estas técnicas es efectiva para combatir el overfitting en una red con varias capas ocultas? Ponga todas las que lo sean.
#
# **a)** Dropout
#
# **b)** Regularización L2.
#
# **c)** Aumentar el tamaño del test set.
#
# **d)** Aumentar el tamaño del validation set.
#
# **e)** Reducir el número de capas de la red.
#
# **f)** Data augmentation.

# %% [markdown]
# a - b - e - f

# %% [markdown]
# <a name='1.8'></a>
# ## Cuestión 8:  Supongamos que queremos entrenar una red para un problema de clasificación de imágenes con las siguientes clases: {'perro','gato','persona'}. ¿Cuántas neuronas y que función de activación debería tener la capa de salida? ¿Qué función de pérdida (loss function) debería usarse?

# %% [markdown]
# El número de neuronas en la capa de salida deberian ser 3, con la funcion de activacion softmax porque es un problema multiclase.
# Y la función de pérdida para un problema de clasificacion multiclase como este, seria: Categorical Cross-Entropy

# %% [markdown]
# <a name='actividad_2'></a>
# # Actividad 2: Redes Convolucionales
#
# Vamos a usar el dataset [cifar-10](https://www.cs.toronto.edu/~kriz/cifar.html), que son 60000 imágenes de 32x32 a color  con 10 clases diferentes. Para realizar mejor la práctica puede consultar [Introduction_to_CNN.ipynb](https://github.com/ezponda/intro_deep_learning/blob/main/class/CNN/Introduction_to_CNN.ipynb).
#
#
#
# **Puntuación**:
#
# - [Cuestión 1](#2.1): 2.5 pt
# - [Cuestión 2](#2.2): 1 pt
# - [Cuestión 3](#2.3): 0.5 pts
# - [Cuestión 4](#2.4): 0.5 pts
# - [Cuestión 5](#2.5): 0.5 pts
#
# Puede normalizar las imágenes al principio o usar la capa [Rescaling](https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/Rescaling):
#
# ```python
# tf.keras.layers.experimental.preprocessing.Rescaling(
#     scale, offset=0.0, name=None, **kwargs
# )
# ```

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
y_train = y_train.flatten()
y_test = y_test.flatten()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i])
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
print('x_train, y_train shapes:', x_train.shape, y_train.shape)
print('x_test, y_test shapes:', x_test.shape, y_test.shape)

# %% [markdown]
# <a name='2.1'></a>
# ## Cuestión 1: Cree una red convolucional con la API funcional con al menos dos capas convolucionales y al menos dos capas de pooling. Debe obtener un `Test accuracy > 0.68`

# %%
inputs = tf.keras.Input(shape=..., name='input')
# reescaling = ...

# Convolution + pooling layers
...

# Flattening
...

# Fully-connected
outputs = layers.Dense(...)

model = keras.Model(inputs=..., outputs=...)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=25, batch_size=64,
                    validation_split=0.15)

# %%
results = model.evaluate(x_test, y_test, verbose=0, batch_size=1000)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %% [markdown]
# <a name='2.2'></a>
# ## Cuestión 2: Cree el mismo  modelo de manera secuencial. No es necesario compilar ni entrenar el modelo

# %%
model_seq = tf.keras.models.Sequential()
# Código aquí
...

# %% [markdown]
# <a name='2.3'></a>
# ## Cuestión 3: Si tenenemos una  una imagen de entrada de 300 x 300 a color (RGB) y queremos usar una red densa. Si la primera capa oculta tiene 100 neuronas, ¿Cuántos parámetros tendrá esa capa (sin incluir el bias) ?

# %% [markdown]
# <a name='2.4'></a>
# ## Cuestión 4   Ponga  las verdaderas ventajas de las redes convolucionales respecto a las densas
#
# **a)** Reducen el número total de parámetros, reduciendo así el overfitting.
#
# **b)** Permiten utilizar una misma 'función'  en varias localizaciones de la imagen de entrada, en lugar de aprender una función diferente para cada pixel.
#
# **c)** Permiten el uso del transfer learning.
#
# **d)** Generalmente son menos profundas, lo que facilita su entrenamiento.

# %% [markdown]
# <a name='2.5'></a>
# ## Cuestión 5: Para el procesamiento de series temporales las redes convolucionales no son efectivas, habrá que usar redes recurrentes.
#
# - **Verdadero**
# - **Falso**
